# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import meta-dataset
dataset = pd.read_csv('dummy_dataset.csv')
X = dataset.iloc[:,:7] # features 
y = dataset.loc[:,'label'] # labels
print(y)
# Out:
# 0               Idle
# 1               Idle
# 2               Idle
# 3               Idle
# 4               Idle
#             ...
# 10881    Volume-Down
# 10882    Volume-Down
# 10883    Volume-Down
# 10884    Volume-Down
# 10885    Volume-Down
# Name: label, Length: 10886, dtype: object

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# KNN model
knn_classifier = KNeighborsClassifier(n_neighbors=3)
knn_classifier.fit(X_train, y_train)
print(classification_report(y_test, knn_classifier.predict(X_test)))
# Out:
#                precision    recall  f1-score   support
#
#          Idle       0.96      0.98      0.97        65
#     Next-Song       0.35      0.42      0.38       223
# Previous-Song       0.49      0.46      0.47       221
#   Volume-Down       0.77      0.79      0.78      1425
#     Volume-Up       0.70      0.66      0.68      1332
#
#      accuracy                           0.70      3266
#     macro avg       0.65      0.66      0.66      3266
#  weighted avg       0.70      0.70      0.70      3266
